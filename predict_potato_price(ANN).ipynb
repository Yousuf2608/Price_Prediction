# %%
## import library anandd modules

import tensorflow as tf
from tensorflow import keras
import pandas as pd  ## to manipulate data
import numpy as np
import matplotlib.pyplot as plt   ## to show data graphically

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-270b6d04-1a60-416f-bba8-fdcd5d3dcdaa" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-270b6d04-1a60-416f-bba8-fdcd5d3dcdaa">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_excel('PotatoPrice.xlsx')

# %%
X = df[['potato_kg']] ## X is a two dimensional or 2D array
Y = df['price']

# %%
# split dataset for train and test
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3)

# %%
X_train
# Out:
#    potato_kg
# 5          6
# 8          9
# 9         10
# 3          4
# 6          7
# 4          5
# 1          2

# %%
# ANN model building
model =bmodeluilding tf.keras.Sequential([
    tf.keras.layers.Dense(1, input_shape=[1],activation='linear')
])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
#compile the ANN model
model.compile( optimizer='sgd', loss= 'mean_squared_error', metrics=['accuracy'])

# %%
#train ANN model
model.fit(X_train,Y_train, epochs=50)
# Out:
# Epoch 1/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step - accuracy: 0.0000e+00 - loss: 23.7288
# Epoch 2/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.0000e+00 - loss: 23.6824
# Epoch 3/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.0000e+00 - loss: 23.6362
# Epoch 4/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.0000e+00 - loss: 23.5903
# Epoch 5/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.0000e+00 - loss: 23.5447
# Epoch 6/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.0000e+00 - loss: 23.4993
# Epoch 7/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.0000e+00 - loss: 23.4543
# Epoch 8/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.0000e+00 - loss: 23.4095
# Epoch 9/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.0000e+00 - loss: 23.3649
# Epoch 10/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.0000e+00 - loss: 23.3206
# Epoch 11/50
# ...

# %%
X_test
# Out:
#    potato_kg
# 2          3
# 7          8
# 0          1
